# %% [markdown]
# <a href="https://www.kaggle.com/code/imranfaroouq/corn-or-maize-leaf-classification-98-accuracy?scriptVersionId=149188934" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Importing Libraries and Modules

# %%
import numpy as np 
import pandas as pd
import tensorflow as tf
from tensorflow.keras import models,layers
import matplotlib.pyplot as plt

# %%
IMAGE_SIZE = (256,256)
BATCH_SIZE = 32

# %% [markdown]
# # Importing Images

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "/kaggle/input/corn-or-maize-leaf-disease-dataset/data",
    shuffle=True,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE
)
# Out:
# Found 4188 files belonging to 4 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Blight', 'Common_Rust', 'Gray_Leaf_Spot', 'Healthy']

# %%
len(dataset)
# Out:
# 131

# %%
plt.figure(figsize=(10,10))
for image_batch , label_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype('uint8'))
        plt.title(class_names[label_batch[i]])
        plt.axis('off')

# %% [markdown]
# # Train-test Split

# %%
def get_dataset(ds,train_split=0.8,val_split=0.1,test_split=0.1,shuffle=True,shuffle_size=10000):
    ds_size = len(ds)
    
    if shuffle:
        ds = ds.shuffle(shuffle_size,seed=8)

    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)

    train_ds = ds.take(train_size)
    
    val_ds = ds.skip(train_size).take(val_size) 
    test_ds = ds.skip(train_size).skip(val_size)
    
    return train_ds,val_ds,test_ds

# %%
train_ds,val_ds,test_ds = get_dataset(dataset)

# %%
print("Length of Training Dataset is",len(train_ds))
print("\nLength of Validation Dataset is",len(val_ds))
print("\nLength of Testing Dataset is",len(test_ds))
# Out:
# Length of Training Dataset is 104
#
# Length of Validation Dataset is 13
#
# Length of Testing Dataset is 14

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
layers.experimental.preprocessing.Resizing(256,256),
layers.experimental.preprocessing.Rescaling(1.0/255)
])

# %% [markdown]
# # Model Building

# %%
n_classes = 4
input_shape = (BATCH_SIZE,256,256,3)
model = models.Sequential([
    resize_and_rescale,
    layers.Conv2D(32,(3,3),activation ='relu',input_shape = input_shape),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size = (3,3),activation ='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size = (3,3),activation ='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size = (3,3),activation ='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size = (3,3),activation ='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size = (3,3),activation ='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Flatten(),
    layers.Dense(64,activation='relu'),
    layers.Dense(n_classes,activation='softmax'),
    
])
model.build(input_shape=input_shape)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (32, 256, 256, 3)         0
#
#  conv2d (Conv2D)             (32, 254, 254, 32)        896
#
#  max_pooling2d (MaxPooling2D  (32, 127, 127, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (32, 125, 125, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (32, 62, 62, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (32, 60, 60, 64)          36928
#
#  max_pooling2d_2 (MaxPooling  (32, 30, 30, 64)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (32, 28, 28, 64)          36928
#
#  max_pooling2d_3 (MaxPooling  (32, 14, 14, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (32, 12, 12, 64)          36928
#
#  max_pooling2d_4 (MaxPooling  (32, 6, 6, 64)           0
#  2D)
#
#  conv2d_5 (Conv2D)           (32, 4, 4, 64)            36928
#
#  max_pooling2d_5 (MaxPooling  (32, 2, 2, 64)           0
#  2D)
#
#  flatten (Flatten)           (32, 256)                 0
#
#  dense (Dense)               (32, 64)                  16448
#
#  dense_1 (Dense)             (32, 4)                   260
#
# =================================================================
# Total params: 183,812
# Trainable params: 183,812
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
optimizer='adam',
loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
metrics=['accuracy']
)

# %% [markdown]
# # Model Fitting

# %%
history = model.fit(
train_ds,
epochs=30,
batch_size=BATCH_SIZE,
verbose=1,
validation_data=val_ds)
# Out:
# Epoch 1/30
# 104/104 [==============================] - 44s 142ms/step - loss: 0.7583 - accuracy: 0.6793 - val_loss: 0.4833 - val_accuracy: 0.8149
# Epoch 2/30
# 104/104 [==============================] - 6s 58ms/step - loss: 0.4222 - accuracy: 0.8285 - val_loss: 0.4695 - val_accuracy: 0.8293
# Epoch 3/30
# 104/104 [==============================] - 6s 58ms/step - loss: 0.3497 - accuracy: 0.8571 - val_loss: 0.3636 - val_accuracy: 0.8726
# Epoch 4/30
# 104/104 [==============================] - 6s 58ms/step - loss: 0.3157 - accuracy: 0.8773 - val_loss: 0.3087 - val_accuracy: 0.8750
# Epoch 5/30
# 104/104 [==============================] - 6s 58ms/step - loss: 0.3210 - accuracy: 0.8761 - val_loss: 0.3018 - val_accuracy: 0.8702
# Epoch 6/30
# 104/104 [==============================] - 6s 58ms/step - loss: 0.2654 - accuracy: 0.8971 - val_loss: 0.2619 - val_accuracy: 0.8894
# Epoch 7/30
# 104/104 [==============================] - 6s 58ms/step - loss: 0.2522 - accuracy: 0.9055 - val_loss: 0.2294 - val_accuracy: 0.8990
# Epoch 8/30
# 104/104 [==============================] - 6s 58ms/step - loss: 0.2426 - accuracy: 0.9106 - val_loss: 0.2443 - val_accuracy: 0.9014
# Epoch 9/30
# 104/104 [==============================] - 6s 58ms/step - loss: 0.2330 - accuracy: 0.9034 - val_loss: 0.2339 - val_accuracy: 0.9207
# Epoch 10/30
# 104/104 [==============================] - 6s 58ms/step - loss: 0.1954 - accuracy: 0.9215 - val_loss: 0.4366 - val_accuracy: 0.8654
# Epoch 11/30
# 104/104 [==============================] - 6s 58ms/step - loss: 0.2639 - accuracy: 0.9001 - val_loss: 0.2188 - val_accuracy: 0.8942
# Epoch 12/30
# 104/104 [==============================] - 6s 58ms/step - loss: 0.1695 - accuracy: 0.9356 - val_loss: 0.1789 - val_accuracy: 0.9471
# Epoch 13/30
# 104/104 [==============================] - 6s 58ms/step - loss: 0.1478 - accuracy: 0.9428 - val_loss: 0.1679 - val_accuracy: 0.9447
# Epoch 14/30
# 104/104 [==============================] - 6s 58ms/step - loss: 0.1253 - accuracy: 0.9510 - val_loss: 0.1696 - val_accuracy: 0.9375
# Epoch 15/30
# 104/104 [==============================] - 6s 58ms/step - loss: 0.1072 - accuracy: 0.9570 - val_loss: 0.1687 - val_accuracy: 0.9399
# Epoch 16/30
# 104/104 [==============================] - 6s 58ms/step - loss: 0.1076 - accuracy: 0.9597 - val_loss: 0.1577 - val_accuracy: 0.9351
# Epoch 17/30
# 104/104 [==============================] - 6s 57ms/step - loss: 0.1026 - accuracy: 0.9633 - val_loss: 0.1501 - val_accuracy: 0.9471
# Epoch 18/30
# 104/104 [==============================] - 6s 57ms/step - loss: 0.0982 - accuracy: 0.9618 - val_loss: 0.1948 - val_accuracy: 0.9351
# Epoch 19/30
# 104/104 [==============================] - 6s 57ms/step - loss: 0.0559 - accuracy: 0.9807 - val_loss: 0.1360 - val_accuracy: 0.9712
# Epoch 20/30
# 104/104 [==============================] - 6s 57ms/step - loss: 0.0489 - accuracy: 0.9856 - val_loss: 0.1911 - val_accuracy: 0.9543
# Epoch 21/30
# 104/104 [==============================] - 6s 58ms/step - loss: 0.0747 - accuracy: 0.9744 - val_loss: 0.1510 - val_accuracy: 0.9639
# Epoch 22/30
# 104/104 [==============================] - 6s 57ms/step - loss: 0.0707 - accuracy: 0.9780 - val_loss: 0.2583 - val_accuracy: 0.9471
# Epoch 23/30
# 104/104 [==============================] - 6s 57ms/step - loss: 0.0626 - accuracy: 0.9826 - val_loss: 0.1433 - val_accuracy: 0.9471
# Epoch 24/30
# 104/104 [==============================] - 6s 57ms/step - loss: 0.0418 - accuracy: 0.9868 - val_loss: 0.1587 - val_accuracy: 0.9591
# Epoch 25/30
# 104/104 [==============================] - 6s 57ms/step - loss: 0.0304 - accuracy: 0.9910 - val_loss: 0.1573 - val_accuracy: 0.9663
# Epoch 26/30
# 104/104 [==============================] - 6s 58ms/step - loss: 0.0337 - accuracy: 0.9916 - val_loss: 0.1456 - val_accuracy: 0.9688
# Epoch 27/30
# 104/104 [==============================] - 6s 57ms/step - loss: 0.0227 - accuracy: 0.9955 - val_loss: 0.1594 - val_accuracy: 0.9760
# Epoch 28/30
# 104/104 [==============================] - 6s 58ms/step - loss: 0.0436 - accuracy: 0.9886 - val_loss: 0.2207 - val_accuracy: 0.9543
# Epoch 29/30
# 104/104 [==============================] - 6s 57ms/step - loss: 0.0553 - accuracy: 0.9868 - val_loss: 0.1945 - val_accuracy: 0.9639
# Epoch 30/30
# 104/104 [==============================] - 6s 57ms/step - loss: 0.0265 - accuracy: 0.9916 - val_loss: 0.1121 - val_accuracy: 0.9760

# %%
scores = model.evaluate(test_ds)
# Out:
# 14/14 [==============================] - 8s 25ms/step - loss: 0.1825 - accuracy: 0.9598

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
his_data = pd.DataFrame(history.history)
plt.figure(figsize=(20,5))

plt.subplot(1,2,1)
plt.plot(his_data.loss, label="Training loss")
plt.plot(his_data.val_loss, label="Validation loss")
plt.xlabel("Epochs")
plt.ylabel("loss")
plt.title("Losses")
plt.grid()
plt.legend()

plt.subplot(1,2,2)
plt.plot(his_data.accuracy, label="Training accuracy")
plt.plot(his_data.val_accuracy, label="Validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Accuracy")
plt.grid()
plt.legend()

# %% [markdown]
# # Prediction

# %%
import numpy as np
for images_batch, labels_batch in test_ds.take(1):
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()
    print("First Image to Predict :")
    plt.imshow(first_image)
    print("\nActual label:",class_names[first_label])
    batch_prediction = model.predict(images_batch) 
    print("\nPredicted label" ,class_names[np.argmax(batch_prediction[0])])
# Out:
# First Image to Predict :
#
# Actual label: Gray_Leaf_Spot
# 1/1 [==============================] - 0s 183ms/step
#
# Predicted label Gray_Leaf_Spot

# %%
def predict(model,img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0) # Create a batch
    predictions = model.predict (img_array)
    predicted_class = class_names[np.argmax(predictions[0])]
#     confidence = round(np.max(predictions[0]),2)
    confidence = round(100*(np.max(predictions[0])),2)

    return predicted_class, confidence

# %%
plt.figure(figsize=(15,15))
for images,labels in test_ds.take(1):
    for i in range(12):
        ax = plt.subplot(3,4,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class , confidence = predict(model,images[i].numpy())
        actual_class = class_names[labels[i]]
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class},\n Confidence Score: {confidence}%")
        plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 287ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step

# %%
# model_version = 1
model.save('/kaggle/working/Disease_Classifier')
